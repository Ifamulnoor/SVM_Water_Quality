# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('waterQuality12.csv')
df
# Out:
#       aluminium  ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 0          1.65     9.08     0.04    2.85    0.007        0.35      0.83
# 1          2.32    21.16     0.01    3.31    0.002        5.28      0.68
# 2          1.01    14.02     0.04    0.58    0.008        4.24      0.53
# 3          1.36    11.33     0.04    2.96    0.001        7.23      0.03
# 4          0.92    24.33     0.03    0.20    0.006        2.67      0.69
# ...         ...      ...      ...     ...      ...         ...       ...
# 7994       0.05     7.78     0.00    1.95    0.040        0.10      0.03
# 7995       0.05    24.22     0.02    0.59    0.010        0.45      0.02
# 7996       0.09     6.85     0.00    0.61    0.030        0.05      0.05
# 7997       0.01    10.00     0.01    2.00    0.000        2.00      0.00
# 7998       0.04     6.85     0.01    0.70    0.030        0.05      0.01
#
#       copper  flouride  bacteria  ...   lead  nitrates  nitrites  mercury  \
# ...

# %%
df.head(7)
# Out:
#    aluminium  ammonia  arsenic  barium  cadmium  chloramine  chromium  copper  \
# 0       1.65     9.08     0.04    2.85    0.007        0.35      0.83    0.17
# 1       2.32    21.16     0.01    3.31    0.002        5.28      0.68    0.66
# 2       1.01    14.02     0.04    0.58    0.008        4.24      0.53    0.02
# 3       1.36    11.33     0.04    2.96    0.001        7.23      0.03    1.66
# 4       0.92    24.33     0.03    0.20    0.006        2.67      0.69    0.57
# 5       0.94    14.47     0.03    2.88    0.003        0.80      0.43    1.38
# 6       2.36     5.60     0.01    1.35    0.004        1.28      0.62    1.88
#
#    flouride  bacteria  ...   lead  nitrates  nitrites  mercury  perchlorate  \
# 0      0.05      0.20  ...  0.054     16.08      1.13    0.007        37.75
# 1      0.90      0.65  ...  0.100      2.01      1.93    0.003        32.26
# 2      0.99      0.05  ...  0.078     14.16      1.11    0.006        50.28
# ...

# %%
df['is_safe'].value_counts().plot(kind='bar')
plt.xlabel('Safe (1) / Not Safe (0)')
plt.ylabel('Count')
plt.title('Distribution of Safe/Not Safe')
plt.show()

# %%
df=pd.read_csv('waterQuality12.csv')
df.head(7)
# Out:
#    aluminium  ammonia  arsenic  barium  cadmium  chloramine  chromium  copper  \
# 0       1.65     9.08     0.04    2.85    0.007        0.35      0.83    0.17
# 1       2.32    21.16     0.01    3.31    0.002        5.28      0.68    0.66
# 2       1.01    14.02     0.04    0.58    0.008        4.24      0.53    0.02
# 3       1.36    11.33     0.04    2.96    0.001        7.23      0.03    1.66
# 4       0.92    24.33     0.03    0.20    0.006        2.67      0.69    0.57
# 5       0.94    14.47     0.03    2.88    0.003        0.80      0.43    1.38
# 6       2.36     5.60     0.01    1.35    0.004        1.28      0.62    1.88
#
#    flouride  bacteria  ...   lead  nitrates  nitrites  mercury  perchlorate  \
# 0      0.05      0.20  ...  0.054     16.08      1.13    0.007        37.75
# 1      0.90      0.65  ...  0.100      2.01      1.93    0.003        32.26
# 2      0.99      0.05  ...  0.078     14.16      1.11    0.006        50.28
# ...

# %%
df.shape
# Out:
# (7999, 21)

# %%
df.size
# Out:
# 167979

# %%
df.isnull().sum()
# Out:
# aluminium      0
# ammonia        0
# arsenic        0
# barium         0
# cadmium        0
# chloramine     0
# chromium       0
# copper         0
# flouride       0
# bacteria       0
# viruses        0
# lead           0
# nitrates       0
# nitrites       0
# mercury        0
# perchlorate    0
# radium         0
# selenium       0
# silver         0
# uranium        0
# is_safe        0
# dtype: int64

# %%
df.dtypes
# Out:
# aluminium      float64
# ammonia        float64
# arsenic        float64
# barium         float64
# cadmium        float64
# chloramine     float64
# chromium       float64
# copper         float64
# flouride       float64
# bacteria       float64
# viruses        float64
# lead           float64
# nitrates       float64
# nitrites       float64
# mercury        float64
# perchlorate    float64
# radium         float64
# selenium       float64
# silver         float64
# uranium        float64
# is_safe          int64
# dtype: object

# %%
X=df.iloc[:,0:-1].values
y=df.iloc[:,-1].values

# %%
X
# Out:
# array([[1.650e+00, 9.080e+00, 4.000e-02, ..., 8.000e-02, 3.400e-01,
#         2.000e-02],
#        [2.320e+00, 2.116e+01, 1.000e-02, ..., 8.000e-02, 2.700e-01,
#         5.000e-02],
#        [1.010e+00, 1.402e+01, 4.000e-02, ..., 7.000e-02, 4.400e-01,
#         1.000e-02],
#        ...,
#        [9.000e-02, 6.850e+00, 0.000e+00, ..., 0.000e+00, 4.000e-02,
#         5.000e-02],
#        [1.000e-02, 1.000e+01, 1.000e-02, ..., 0.000e+00, 0.000e+00,
#         0.000e+00],
#        [4.000e-02, 6.850e+00, 1.000e-02, ..., 0.000e+00, 4.000e-02,
#         5.000e-02]])

# %%
y
# Out:
# array([1, 1, 0, ..., 1, 1, 1], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
print(X_train)
# Out:
# [[2.370e+00 2.106e+01 3.500e-01 ... 8.000e-02 2.700e-01 5.000e-02]
#  [7.000e-02 1.769e+01 2.000e-02 ... 4.000e-02 7.000e-02 1.000e-02]
#  [7.000e-02 1.100e+00 3.000e-02 ... 1.000e-01 1.000e-02 0.000e+00]
#  ...
#  [2.380e+00 1.613e+01 3.300e-01 ... 9.000e-02 2.800e-01 8.000e-02]
#  [3.000e-02 1.891e+01 2.000e-02 ... 8.000e-02 4.600e-01 2.000e-02]
#  [1.500e-01 1.042e+01 5.000e-02 ... 3.000e-02 6.000e-02 4.000e-02]]

# %%
print(X_test)
# Out:
# [[6.000e-02 1.493e+01 5.000e-02 ... 5.000e-02 4.100e-01 4.000e-02]
#  [3.590e+00 4.120e+00 3.800e-01 ... 6.000e-02 2.300e-01 8.000e-02]
#  [2.000e-02 6.380e+00 2.000e-02 ... 1.000e-02 7.000e-02 9.000e-02]
#  ...
#  [8.000e-02 2.303e+01 1.500e-01 ... 7.000e-02 4.500e-01 8.000e-02]
#  [1.970e+00 2.376e+01 3.800e-01 ... 3.000e-02 4.600e-01 0.000e+00]
#  [1.100e-01 8.980e+00 1.600e-01 ... 8.000e-02 3.400e-01 2.000e-02]]

# %%
print(y_train)
# Out:
# [0 0 0 ... 0 0 0]

# %%
print(y_test)
# Out:
# [0 0 0 ... 0 0 0]

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state = 0) #you can use other kernels as well
classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn import metrics

cm = metrics.confusion_matrix(y_test, y_pred)
print(cm)
cm_display=metrics.ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=classifier.classes_)
cm_display.plot()
# Out:
# [[1397   26]
#  [ 128   49]]

# %%
from sklearn.metrics import classification_report
report=classification_report(y_test,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      1423
#            1       0.65      0.28      0.39       177
#
#     accuracy                           0.90      1600
#    macro avg       0.78      0.63      0.67      1600
# weighted avg       0.89      0.90      0.89      1600
